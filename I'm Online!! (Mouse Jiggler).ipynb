# %% [markdown]
# # Mouse Jiggler
#
# - Periodically move the mouse / enter keystrokes
# - Keep productivity apps active

# %%
import pyautogui
import time

# %%
while True:
    pyautogui.moveRel(0, 50, duration = 1)
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-094bedc150ac> in <module>
#       1 while True:
#       2     pyautogui.moveRel(0, 50, duration = 1)
# ----> 3     time.sleep(1)
#
# KeyboardInterrupt:
